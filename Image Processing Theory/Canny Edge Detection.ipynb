# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('colorGradient.jpg',0)
# apply gaussian filter to the image or apply a smoothening transform to the image.
# here we use a 5 by 5 averaging convolutional average matrix( I sound like Pro :P )

# kernel = np.ones((4,4),np.float32)/25
# dst = cv2.filter2D(img,-1,kernel)

edges = cv2.Canny(img,100,200)

plt.subplot(221),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# plt.subplot(223),plt.imshow(dst,cmap = 'gray')
# plt.title('New Image'), plt.xticks([]), plt.yticks([])
# cv2.imshow('Smoothened image dst',dst)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.show()
